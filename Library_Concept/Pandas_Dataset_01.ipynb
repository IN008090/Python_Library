# %%
import matplotlib.pyplot as plt 
import pandas as pd   # df=DATAFRAME & pd is the module of pandas
df=pd.read_csv('weather.csv')  # Code to import the csv file into jupyter.
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df["Sunshine"].max()
# Out:
# 13.6

# %%
df["MaxTemp"].max()
# Out:
# 35.8

# %%
df["MinTemp"].min()
# Out:
# -5.3

# %%
df["Pressure3pm"][df["WindDir3pm"]=="NW"]  # Here need to take two arugment to do filter of the required data
# Out:
# 0      1015.0
# 10     1021.1
# 11     1019.9
# 12     1017.1
# 20     1006.5
#         ...
# 350    1022.3
# 352    1022.2
# 353    1019.8
# 354    1017.5
# 361    1010.8
# Name: Pressure3pm, Length: 61, dtype: float64

# %%
df["Humidity3pm"].mean() # To find the mean
# Out:
# 44.51912568306011

# %% [markdown]
# ## Extra Info

# %%
df.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
df.isnull().dropna(0)
# Out:
# C:\Users\Joshi's.DESKTOP-JTVUBQS\AppData\Local\Temp\ipykernel_11432\2016325749.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df.isnull().dropna(0)
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0      False    False     False        False     False        False
# 1      False    False     False        False     False        False
# 2      False    False     False        False     False        False
# 3      False    False     False        False     False        False
# 4      False    False     False        False     False        False
# ..       ...      ...       ...          ...       ...          ...
# 361    False    False     False        False     False        False
# 362    False    False     False        False     False        False
# 363    False    False     False        False     False        False
# 364    False    False     False        False     False        False
# ...

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
df.isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# RainTomorrow     0
# dtype: int64

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
new_df=df.drop(columns=['Humidity3pm','Temp3pm','Sunshine','RainToday','RainTomorrow','WindGustDir','WindDir9am','WindDir3pm','RISK_MM','Pressure3pm','Cloud3pm','WindSpeed3pm'])
new_df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  WindGustSpeed  WindSpeed9am  \
# 0        8.0     24.3       0.0          3.4           30.0           6.0
# 1       14.0     26.9       3.6          4.4           39.0           4.0
# 2       13.7     23.4       3.6          5.8           85.0           6.0
# 3       13.3     15.5      39.8          7.2           54.0          30.0
# 4        7.6     16.1       2.8          5.6           50.0          20.0
# ..       ...      ...       ...          ...            ...           ...
# 361      9.0     30.7       0.0          7.6           76.0           7.0
# 362      7.1     28.4       0.0         11.6           48.0           2.0
# 363     12.5     19.9       0.0          8.4           43.0          11.0
# 364     12.5     26.9       0.0          5.0           46.0           6.0
# 365     12.3     30.2       0.0          6.0           78.0          31.0
#
#      Humidity9am  Pressure9am  Cloud9am  Temp9am
# ...

# %%
X=new_df
X
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  WindGustSpeed  WindSpeed9am  \
# 0        8.0     24.3       0.0          3.4           30.0           6.0
# 1       14.0     26.9       3.6          4.4           39.0           4.0
# 2       13.7     23.4       3.6          5.8           85.0           6.0
# 3       13.3     15.5      39.8          7.2           54.0          30.0
# 4        7.6     16.1       2.8          5.6           50.0          20.0
# ..       ...      ...       ...          ...            ...           ...
# 361      9.0     30.7       0.0          7.6           76.0           7.0
# 362      7.1     28.4       0.0         11.6           48.0           2.0
# 363     12.5     19.9       0.0          8.4           43.0          11.0
# 364     12.5     26.9       0.0          5.0           46.0           6.0
# 365     12.3     30.2       0.0          6.0           78.0          31.0
#
#      Humidity9am  Pressure9am  Cloud9am  Temp9am
# ...

# %%
y=df.RainToday
y
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
#       ...
# 361     No
# 362     No
# 363     No
# 364     No
# 365     No
# Name: RainToday, Length: 328, dtype: object

# %%
y=pd.get_dummies(y)
y
# Out:
#      No  Yes
# 0     1    0
# 1     0    1
# 2     0    1
# 3     0    1
# 4     0    1
# ..   ..  ...
# 361   1    0
# 362   1    0
# 363   1    0
# 364   1    0
# 365   1    0
#
# [328 rows x 2 columns]

# %%
new_df=pd.concat([X,y],axis='columns')
new_df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  WindGustSpeed  WindSpeed9am  \
# 0        8.0     24.3       0.0          3.4           30.0           6.0
# 1       14.0     26.9       3.6          4.4           39.0           4.0
# 2       13.7     23.4       3.6          5.8           85.0           6.0
# 3       13.3     15.5      39.8          7.2           54.0          30.0
# 4        7.6     16.1       2.8          5.6           50.0          20.0
# ..       ...      ...       ...          ...            ...           ...
# 361      9.0     30.7       0.0          7.6           76.0           7.0
# 362      7.1     28.4       0.0         11.6           48.0           2.0
# 363     12.5     19.9       0.0          8.4           43.0          11.0
# 364     12.5     26.9       0.0          5.0           46.0           6.0
# 365     12.3     30.2       0.0          6.0           78.0          31.0
#
#      Humidity9am  Pressure9am  Cloud9am  Temp9am  No  Yes
# ...

# %%
new_df=new_df['Rainfall']
new_df
# Out:
# 0       0.0
# 1       3.6
# 2       3.6
# 3      39.8
# 4       2.8
#        ...
# 361     0.0
# 362     0.0
# 363     0.0
# 364     0.0
# 365     0.0
# Name: Rainfall, Length: 328, dtype: float64

# %%
import seaborn as sns
# %matplotlib inline   
plt.xlabel('happening_rain')
plt.ylabel('happened')
plt.subplot(1,3,1)
sns.countplot('Rainfall',hue='y')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 6>()
#       4 plt.ylabel('happened')
#       5 plt.subplot(1,3,1)
# ----> 6 sns.countplot('Rainfall',hue='y')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
# ...

# %%
rain_f.shape

# %%
y.shape

# %%
rez=preprocessing.OneHotEncoder()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 rez=preprocessing.OneHotEncoder()
#
# NameError: name 'preprocessing' is not defined

# %%
from sklearn.model_selection import train_test_split
X_train,y_train,X_test,y_test=train_test_split(X,y,train_size=0.3)

# %%
from sklearn import linear_model 
from sklearn.linear_model import LinearRegression

# %%
model_l=linear_model.LinearRegression()

# %%
model_l.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 model_l.fit(X_train,y_train)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# ...
